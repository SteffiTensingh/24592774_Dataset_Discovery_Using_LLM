# %%
import pandas as pd 
Metadata_DS = pd.read_csv('C:\\24592774_Dataset_Discovery_Using_LLM\\MetaData_Creation\\Metadata_Data\\MetaData_DataSet.csv')
for column in Metadata_DS.columns:
    print(f"Column: {column}")
    print(f"Number of unique values: {Metadata_DS[column].nunique()}")
    print(f"Number of missing values: {Metadata_DS[column].isnull().sum()}")
    print(f"Sample values: {Metadata_DS[column].sample(5).tolist()}")
    print("-" * 50)
# Out:
# Column: owner
# Number of unique values: 51
# Number of missing values: 0
# Sample values: ['rtekumalla1', 'city-of-ny', 'datagov-uk', 'us-nasa-gov', 'datagov-uk']
# --------------------------------------------------
# Column: id
# Number of unique values: 84
# Number of missing values: 0
# Sample values: ['buy-wireless-security-cameras-at-affordable-prices', '49f680f8-282b-4044-b156-14116bc68367', '297027e8-3297-40e2-8a12-c7c9c124dc0b', 'food-ingredient-lists', 'ifc-enterprise-finance-raw']
# --------------------------------------------------
# Column: title
# Number of unique values: 83
# Number of missing values: 0
# Sample values: ['Impact of uncoordinated plug-in electric vehicle charging...', 'Water pollution, substantiated incidents', 'Electric Vehicle Charging Stations', 'legalMap', 'UN: Population Growth Rate (XL']
# --------------------------------------------------
# Column: description
# Number of unique values: 79
# Number of missing values: 0
# ...

# %%
print("Data Types:")
print(Metadata_DS.dtypes)
# Out:
# Data Types:
# owner          object
# id             object
# title          object
# description    object
# summary        object
# version        object
# tags           object
# dois           object
# visibility     object
# files          object
# status         object
# created        object
# updated        object
# accessLevel    object
# versionDois    object
# isProject        bool
# properties     object
# license        object
# assetStatus    object
# dataset_url    object
# dtype: object

# %%
Metadata_DS.head()
# Out:
#              owner                                    id  \
# 0   makeovermonday                                2023w7
# 1  smartcolumbusos  650b7e59-afd3-4c40-9bfc-8d614610b77b
# 2       townofcary    electric-vehicle-charging-stations
# 3      data-ny-gov                             thd2-fu8y
# 4       us-doe-gov  8ae7e117-313b-40b1-b146-83add97d400b
#
#                                                title  \
# 0      2023/W7: Global Electric Vehicle Market Share
# 1              Connected Electric Autonomous Vehicle
# 2                 Electric Vehicle Charging Stations
# 3  NYSERDA Electric Vehicle Drive Clean Rebate Da...
# 4  Impact of uncoordinated plug-in electric vehic...
#
#                                          description  \
# 0               Global Electric Vehicle Market Share
# 1              Connected Electric Autonomous Vehicle
# 2  \n\nThis dataset contains session details from...
# 3  New York State’s Charge NY initiative offers e...
# ...

# %%
categorical_fields = ['owner', 'visibility', 'status', 'accessLevel']
for field in categorical_fields:
    print(f"\nUnique values in {field}:")
    print(Metadata_DS[field].unique())
# Out:
# Unique values in owner:
# ['makeovermonday' 'smartcolumbusos' 'townofcary' 'data-ny-gov'
#  'us-doe-gov' 'jeffgswanson' 'us-epa-gov' 'datagov-uk' 'johnsnowlabs'
#  'john-rager' 'smart-columbus' 'us-nasa-gov' 'romanian-data' 'rajanand'
#  'markmarkoh' 'chandrasekar' 'george-t-stagg' 'crawlfeeds' 'hdx'
#  'us-doi-gov' 'rtekumalla1' 'nhtsa' 'brianray' 'okgoogleassistant' 'kgs1'
#  'eng' 'h0tftw' 'safiat' 'healthdatany' 'chhs' 'nrippner'
#  'cytotecpillsdubai' 'us-hhs-gov' 'liz-friedman' 'finance' 'codefordc'
#  'kongkei' 'freemotion' 'durhamnc' 'datafiniti' 'usda' 'agriculture'
#  'dcopendata' 'sanfrancisco' 'city-of-ny' 'city-of-tempe' 'telangana'
#  'sports' 'crowdflower' 'the-pudding' 'zendoll27']
#
# Unique values in visibility:
# ['OPEN' 'DISCOVERABLE']
#
# Unique values in status:
# ['LOADED']
#
# Unique values in accessLevel:
# ['READ' 'DISCOVER']

# %%
# Check missing values
print("\nMissing Values:")
print(Metadata_DS.isnull().sum())
# Out:
# Missing Values:
# owner          0
# id             0
# title          0
# description    0
# summary        0
# version        0
# tags           0
# dois           0
# visibility     0
# files          0
# status         0
# created        0
# updated        0
# accessLevel    0
# versionDois    0
# isProject      0
# properties     0
# license        0
# assetStatus    0
# dataset_url    0
# dtype: int64

# %%
# Check value distribution
print("\nValue Distribution:")
print(Metadata_DS.describe())
# Out:
# Value Distribution:
#              owner      id                                              title  \
# count           84      84                                                 84
# unique          51      84                                                 83
# top     datagov-uk  2023w7  Impact of uncoordinated plug-in electric vehic...
# freq            16       1                                                  2
#
#        description summary                               version tags dois  \
# count           84      84                                    84   84   84
# unique          79      79                                    84   58    2
# top                         ecbb53fd-4a19-48f6-8479-414eb7efccd4   []
# freq             5       6                                     1   21   69
#
#        visibility files  status                         created  \
# count          84    84      84                              84
# ...

# %% [markdown]
# Dara
