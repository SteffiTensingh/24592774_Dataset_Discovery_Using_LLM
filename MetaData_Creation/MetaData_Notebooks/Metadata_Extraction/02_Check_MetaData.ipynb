# %%
import pandas as pd 
Metadata_DS = pd.read_csv('C:\\Users\\Steffi Grace\\24592774_LLM_ILabResearch\\Notebooks\\Datasets\\New_MetaData_DataSet.csv')
for column in Metadata_DS.columns:
    print(f"Column: {column}")
    print(f"Number of unique values: {Metadata_DS[column].nunique()}")
    print(f"Number of missing values: {Metadata_DS[column].isnull().sum()}")
    print(f"Sample values: {Metadata_DS[column].sample(5).tolist()}")
    print("-" * 50)
# Out:
# Column: owner
# Number of unique values: 4
# Number of missing values: 0
# Sample values: ['hdx', 'alexandra', 'chhs', 'hdx', 'us-hhs-gov']
# --------------------------------------------------
# Column: id
# Number of unique values: 5
# Number of missing values: 0
# Sample values: ['80ded4e2-aa4f-42bc-ad08-6c1effc24123', 'f92954dc-3f5b-407a-80a9-1e178280b0d7', '87c842cf-095a-412e-8cf2-5d87ed07e34b', 'food-related-words', '0114f5bb-4975-419d-95d9-5f0179a8de06']
# --------------------------------------------------
# Column: title
# Number of unique values: 5
# Number of missing values: 0
# Sample values: ['Europe: Coronavirus (COVID-19) Subnational Cases', 'Provisional Death Counts for Coronavirus Disease (COVID-1...', 'Food Affordability', 'The New York Times Coronavirus (Covid-19) Cases and Death...', 'Food related words']
# --------------------------------------------------
# Column: description
# Number of unique values: 5
# Number of missing values: 0
# ...

# %%
print("Data Types:")
print(Metadata_DS.dtypes)
# Out:
# Data Types:
# owner          object
# id             object
# title          object
# description    object
# summary        object
# version        object
# tags           object
# license        object
# visibility     object
# files          object
# status         object
# created        object
# updated        object
# accessLevel    object
# versionDois    object
# isProject        bool
# dataset_url    object
# dtype: object

# %%
Metadata_DS.head()
# Out:
#         owner                                    id  \
# 0         hdx  80ded4e2-aa4f-42bc-ad08-6c1effc24123
# 1         hdx  f92954dc-3f5b-407a-80a9-1e178280b0d7
# 2  us-hhs-gov  87c842cf-095a-412e-8cf2-5d87ed07e34b
# 3   alexandra                    food-related-words
# 4        chhs  0114f5bb-4975-419d-95d9-5f0179a8de06
#
#                                                title  \
# 0   Europe: Coronavirus (COVID-19) Subnational Cases
# 1  The New York Times Coronavirus (Covid-19) Case...
# 2  Provisional Death Counts for Coronavirus Disea...
# 3                                 Food related words
# 4                                 Food Affordability
#
#                                          description  \
# 0   Europe: Coronavirus (COVID-19) Subnational Cases
# 1  The New York Times Coronavirus (Covid-19) Case...
# 2  Provisional Death Counts for Coronavirus Disea...
# 3  7.000 words that relate to food, production of...
# 4  This table contains data on the average cost o...
#
# ...

# %%
categorical_fields = ['owner', 'visibility', 'status', 'accessLevel']
for field in categorical_fields:
    print(f"\nUnique values in {field}:")
    print(Metadata_DS[field].unique())
# Out:
# Unique values in owner:
# ['hdx' 'us-hhs-gov' 'alexandra' 'chhs']
#
# Unique values in visibility:
# ['OPEN']
#
# Unique values in status:
# ['LOADED']
#
# Unique values in accessLevel:
# ['READ']

# %%
# Check missing values
print("\nMissing Values:")
print(Metadata_DS.isnull().sum())
# Out:
# Missing Values:
# owner          0
# id             0
# title          0
# description    0
# summary        0
# version        0
# tags           0
# license        0
# visibility     0
# files          0
# status         0
# created        0
# updated        0
# accessLevel    0
# versionDois    0
# isProject      0
# dataset_url    0
# dtype: int64

# %%
# Check value distribution
print("\nValue Distribution:")
print(Metadata_DS.describe())
# Out:
# Value Distribution:
#        owner                                    id  \
# count      5                                     5
# unique     4                                     5
# top      hdx  80ded4e2-aa4f-42bc-ad08-6c1effc24123
# freq       2                                     1
#
#                                                    title  \
# count                                                  5
# unique                                                 5
# top     Europe: Coronavirus (COVID-19) Subnational Cases
# freq                                                   1
#
#                                              description  \
# count                                                  5
# unique                                                 5
# top     Europe: Coronavirus (COVID-19) Subnational Cases
# freq                                                   1
#
#                                                   summary  \
# ...
